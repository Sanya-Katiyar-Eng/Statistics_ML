# %% [markdown]
# # Standard deviation

# %% [markdown]
# *1. Using numpy*

# %%
import numpy
l=[10,20,30,40,50,60]
S_std=numpy.std(l,ddof=1)
print("Sample standard deviation :",S_std)
P_std=numpy.std(l,ddof=0)
print("Population standard deviation :",P_std)
# Out:
# Sample standard deviation : 18.708286933869708
# Population standard deviation : 17.07825127659933
